# %%
import pickle
import glob
import os
import pandas
import numpy as np
import json

pandas.options.display.float_format = '{:.3f}'.format

# %%
with open('./datasets.json', 'r') as f:
    datasets = json.load(f)

# %%
models = ['SigLSTM', 'SigGRU', 'Sig', 'LSTM', 'GRU', 'KConv1D']
with open('./architectures.json', 'r') as f:
    architectures = json.load(f)
num_experiments = 5

# %% [markdown]
# ### Parse results

# %%
results_dict = {m : {'acc' : {}, 'nlpp' : {}} for m in models}
for k, model in enumerate(models):
    results_folder = './results/GP{}/'.format(model)
    for i, dataset in enumerate(datasets):
        print('Parsing results for model: {} ({}/{}), dataset: {} ({:2d}/{})...'.format(model, k+1, len(models), dataset, i+1, len(datasets)))
        for j in range(num_experiments):
            spec = ''
            if 'GRU' in model or 'LSTM' in model:
                if dataset in architectures[model]:
                    spec = architectures[model][dataset]
                    spec = '_H{}_D{}'.format(spec['H'], spec['D'])
                else:
                    print('Warning: missing architecture spec. for dataset: {} and model: {}'.format(dataset, model))
                    spec = None
                    test_nlpp = float('nan')
                    test_acc = float('nan')
            
            if spec is not None:
                experiment_name = '{}{}_{}'.format(dataset, spec, j)
                file_path = os.path.join(results_folder, experiment_name + '.pkl')
                if os.path.exists(file_path):
                    with open(file_path, 'rb') as f:
                        saved_dict = pickle.load(f)
                    test_acc = saved_dict['results']['test_acc']
                    test_nlpp = saved_dict['results']['test_nlpp']
                else:
                    print('Warning: missing result file {}'.format(file_path))
                    test_acc = float('nan')
                    test_nlpp = float('nan')
                

            if j not in results_dict[model]['acc']:
                results_dict[model]['acc'][j] = []
            results_dict[model]['acc'][j].append(test_acc)

            if j not in results_dict[model]['nlpp']:
                results_dict[model]['nlpp'][j] = []
            results_dict[model]['nlpp'][j].append(test_nlpp)
# Out:
# Parsing results for model: SigLSTM (1/6), dataset: ArabicDigits ( 1/16)...
# Parsing results for model: SigLSTM (1/6), dataset: AUSLAN ( 2/16)...
# Parsing results for model: SigLSTM (1/6), dataset: CharacterTrajectories ( 3/16)...
# Parsing results for model: SigLSTM (1/6), dataset: CMUsubject16 ( 4/16)...
# Parsing results for model: SigLSTM (1/6), dataset: DigitShapes ( 5/16)...
# Parsing results for model: SigLSTM (1/6), dataset: ECG ( 6/16)...
# Parsing results for model: SigLSTM (1/6), dataset: JapaneseVowels ( 7/16)...
# Parsing results for model: SigLSTM (1/6), dataset: KickvsPunch ( 8/16)...
# Parsing results for model: SigLSTM (1/6), dataset: LIBRAS ( 9/16)...
# Parsing results for model: SigLSTM (1/6), dataset: NetFlow (10/16)...
# Parsing results for model: SigLSTM (1/6), dataset: PEMS (11/16)...
# Parsing results for model: SigLSTM (1/6), dataset: PenDigits (12/16)...
# Parsing results for model: SigLSTM (1/6), dataset: Shapes (13/16)...
# Parsing results for model: SigLSTM (1/6), dataset: UWave (14/16)...
# Parsing results for model: SigLSTM (1/6), dataset: Wafer (15/16)...
# Parsing results for model: SigLSTM (1/6), dataset: WalkvsRun (16/16)...
# Parsing results for model: SigGRU (2/6), dataset: ArabicDigits ( 1/16)...
# Parsing results for model: SigGRU (2/6), dataset: AUSLAN ( 2/16)...
# Parsing results for model: SigGRU (2/6), dataset: CharacterTrajectories ( 3/16)...
# Parsing results for model: SigGRU (2/6), dataset: CMUsubject16 ( 4/16)...
# Parsing results for model: SigGRU (2/6), dataset: DigitShapes ( 5/16)...
# Parsing results for model: SigGRU (2/6), dataset: ECG ( 6/16)...
# Parsing results for model: SigGRU (2/6), dataset: JapaneseVowels ( 7/16)...
# Parsing results for model: SigGRU (2/6), dataset: KickvsPunch ( 8/16)...
# Parsing results for model: SigGRU (2/6), dataset: LIBRAS ( 9/16)...
# Parsing results for model: SigGRU (2/6), dataset: NetFlow (10/16)...
# Parsing results for model: SigGRU (2/6), dataset: PEMS (11/16)...
# Parsing results for model: SigGRU (2/6), dataset: PenDigits (12/16)...
# Parsing results for model: SigGRU (2/6), dataset: Shapes (13/16)...
# Parsing results for model: SigGRU (2/6), dataset: UWave (14/16)...
# Parsing results for model: SigGRU (2/6), dataset: Wafer (15/16)...
# Parsing results for model: SigGRU (2/6), dataset: WalkvsRun (16/16)...
# Parsing results for model: Sig (3/6), dataset: ArabicDigits ( 1/16)...
# Parsing results for model: Sig (3/6), dataset: AUSLAN ( 2/16)...
# Parsing results for model: Sig (3/6), dataset: CharacterTrajectories ( 3/16)...
# Parsing results for model: Sig (3/6), dataset: CMUsubject16 ( 4/16)...
# Parsing results for model: Sig (3/6), dataset: DigitShapes ( 5/16)...
# Parsing results for model: Sig (3/6), dataset: ECG ( 6/16)...
# Parsing results for model: Sig (3/6), dataset: JapaneseVowels ( 7/16)...
# Parsing results for model: Sig (3/6), dataset: KickvsPunch ( 8/16)...
# Parsing results for model: Sig (3/6), dataset: LIBRAS ( 9/16)...
# Parsing results for model: Sig (3/6), dataset: NetFlow (10/16)...
# Parsing results for model: Sig (3/6), dataset: PEMS (11/16)...
# Parsing results for model: Sig (3/6), dataset: PenDigits (12/16)...
# Parsing results for model: Sig (3/6), dataset: Shapes (13/16)...
# Parsing results for model: Sig (3/6), dataset: UWave (14/16)...
# Parsing results for model: Sig (3/6), dataset: Wafer (15/16)...
# Parsing results for model: Sig (3/6), dataset: WalkvsRun (16/16)...
# Parsing results for model: LSTM (4/6), dataset: ArabicDigits ( 1/16)...
# Parsing results for model: LSTM (4/6), dataset: AUSLAN ( 2/16)...
# Parsing results for model: LSTM (4/6), dataset: CharacterTrajectories ( 3/16)...
# Parsing results for model: LSTM (4/6), dataset: CMUsubject16 ( 4/16)...
# Parsing results for model: LSTM (4/6), dataset: DigitShapes ( 5/16)...
# Parsing results for model: LSTM (4/6), dataset: ECG ( 6/16)...
# Parsing results for model: LSTM (4/6), dataset: JapaneseVowels ( 7/16)...
# Parsing results for model: LSTM (4/6), dataset: KickvsPunch ( 8/16)...
# Parsing results for model: LSTM (4/6), dataset: LIBRAS ( 9/16)...
# Parsing results for model: LSTM (4/6), dataset: NetFlow (10/16)...
# Parsing results for model: LSTM (4/6), dataset: PEMS (11/16)...
# Parsing results for model: LSTM (4/6), dataset: PenDigits (12/16)...
# Parsing results for model: LSTM (4/6), dataset: Shapes (13/16)...
# Parsing results for model: LSTM (4/6), dataset: UWave (14/16)...
# Parsing results for model: LSTM (4/6), dataset: Wafer (15/16)...
# Parsing results for model: LSTM (4/6), dataset: WalkvsRun (16/16)...
# Parsing results for model: GRU (5/6), dataset: ArabicDigits ( 1/16)...
# Parsing results for model: GRU (5/6), dataset: AUSLAN ( 2/16)...
# Parsing results for model: GRU (5/6), dataset: CharacterTrajectories ( 3/16)...
# Parsing results for model: GRU (5/6), dataset: CMUsubject16 ( 4/16)...
# Parsing results for model: GRU (5/6), dataset: DigitShapes ( 5/16)...
# Parsing results for model: GRU (5/6), dataset: ECG ( 6/16)...
# Parsing results for model: GRU (5/6), dataset: JapaneseVowels ( 7/16)...
# Parsing results for model: GRU (5/6), dataset: KickvsPunch ( 8/16)...
# Parsing results for model: GRU (5/6), dataset: LIBRAS ( 9/16)...
# Parsing results for model: GRU (5/6), dataset: NetFlow (10/16)...
# Parsing results for model: GRU (5/6), dataset: PEMS (11/16)...
# Parsing results for model: GRU (5/6), dataset: PenDigits (12/16)...
# Parsing results for model: GRU (5/6), dataset: Shapes (13/16)...
# Parsing results for model: GRU (5/6), dataset: UWave (14/16)...
# Parsing results for model: GRU (5/6), dataset: Wafer (15/16)...
# Parsing results for model: GRU (5/6), dataset: WalkvsRun (16/16)...
# Parsing results for model: KConv1D (6/6), dataset: ArabicDigits ( 1/16)...
# Parsing results for model: KConv1D (6/6), dataset: AUSLAN ( 2/16)...
# Parsing results for model: KConv1D (6/6), dataset: CharacterTrajectories ( 3/16)...
# Parsing results for model: KConv1D (6/6), dataset: CMUsubject16 ( 4/16)...
# Parsing results for model: KConv1D (6/6), dataset: DigitShapes ( 5/16)...
# Parsing results for model: KConv1D (6/6), dataset: ECG ( 6/16)...
# Parsing results for model: KConv1D (6/6), dataset: JapaneseVowels ( 7/16)...
# Parsing results for model: KConv1D (6/6), dataset: KickvsPunch ( 8/16)...
# Parsing results for model: KConv1D (6/6), dataset: LIBRAS ( 9/16)...
# Parsing results for model: KConv1D (6/6), dataset: NetFlow (10/16)...
# Parsing results for model: KConv1D (6/6), dataset: PEMS (11/16)...
# Parsing results for model: KConv1D (6/6), dataset: PenDigits (12/16)...
# Parsing results for model: KConv1D (6/6), dataset: Shapes (13/16)...
# Parsing results for model: KConv1D (6/6), dataset: UWave (14/16)...
# Parsing results for model: KConv1D (6/6), dataset: Wafer (15/16)...
# Parsing results for model: KConv1D (6/6), dataset: WalkvsRun (16/16)...

# %% [markdown]
# ### Individual results of models over 5 runs

# %%
from IPython.display import display
for model in models:
    
    model_full = '# GP{} #'.format(model)
    print()
    print('#'*len(model_full))
    print(model_full)
    print('#'*len(model_full))
    print()
    
    print('Accuracy:'.format(model))
    df = pandas.DataFrame.from_dict(results_dict[model]['acc']).rename(index={i : name for i, name in enumerate(datasets)})
    df['mean'] = df.mean(axis=1)
    df['std'] = df.std(axis=1)
    display(df)
    
    print('\nNegative log-predictive probability:'.format(model))
    df = pandas.DataFrame.from_dict(results_dict[model]['nlpp']).rename(index={i : name for i, name in enumerate(datasets)})
    df['mean'] = df.mean(axis=1)
    df['std'] = df.std(axis=1)
    display(df)
# Out:
# #############
# # GPSigLSTM #
# #############
#
# Accuracy:
#                           0     1     2     3     4  mean   std
# ArabicDigits          0
# LIBRAS                0.872 0.906 0.939 0.856 0.922 0.899 0.031
# NetFlow               0.919 0.899 0.927 0.931 0.931 0.921 0.012
# PEMS                  0.751 0.786 0.775 0.803 0.757 0.775 0.019
# PenDigits             0.966 0.849 0.941 0.908 0.848 0.902 0.048
# Shapes                1.000 1.000 1.000 1.000 1.000 1.000 0.000
# UWave                 0.957 0.974 0.965 0.972 0.970 0.968 0.006
# Wafer                 0.972 0.980 0.983 0.984 0.972 0.978 0.005
# WalkvsRun             1.000 1.000 1.000 1.000 1.000 1.000 0.000
# Negative log-predictive probability:
#                           0     1     2     3     4  mean   std
# ArabicDigits          0.035 0.020 0.018 0.022 0.019 0.023 0.006
# AUSLAN                0.205 0.084 0.085 0.134 0.108 0.123 0.045
# CharacterTrajectories 0.041 0.521 0.048 0.638 0.044 0.258 0.265
# CMUsubject16          0.042 0.024 0.054 0.042 0.039 0.040 0.009
# DigitShapes           0.010 0.010 0.010 0.137 0.010 0.035 0.051
# ECG                   0.461 0.412 0.423 0.483 0.377 0.431 0.037
# JapaneseVowels        0.052 0.058 0.063 0.053 0.038 0.053 0.009
# KickvsPunch           0.537 0.261 0.460 0.593 0.615 0.493 0.128
# LIBRAS                0.423 0.305 0.242 0.480 0.277 0.346 0.091
# NetFlow               0.289 0.399 0.212 0.200 0.195 0.259 0.078
# PEMS                  1.094 1.099 1.068 1.023 1.216 1.100 0.064
# PenDigits             0.119 0.581 0.265 0.350 0.681 0.399 0.206
# Shapes                0.008 0.015 0.007 0.013 0.016 0.012 0.004
# UWave                 0.149 0.105 0.131 0.104 0.114 0.121 0.017
# Wafer                 0.093 0.081 0.068 0.068 0.093 0.081 0.011
# WalkvsRun             0.031 0.027 0.044 0.026 0.021 0.030 0.008
# #########
# # GPSig #
# #########
#
# Accuracy:
#                           0     1     2     3     4  mean   std
# ArabicDigits          0.980 0.975 0.979 0.976 0.985 0.979 0.004
# AUSLAN                0.947 0.903 0.927 0.930 0.919 0.925 0.014
# CharacterTrajectories 0.977 0.980 0.980 0.980 0.977 0.979 0.002
# CMUsubject16          1.000 0.966 0.966 1.000 0.966 0.979 0.017
# DigitShapes           1.000 1.000 1.000 1.000 1.000 1.000 0.000
# ECG                   0.850 0.850 0.860 0.850 0.830 0.848 0.010
# JapaneseVowels        0.984 0.984 0.978 0.989 0.976 0.982 0.005
# KickvsPunch           0.900 0.900 0.900 0.900 0.900 0.900 0.000
# LIBRAS                0.922 0.928 0.917 0.922 0.928 0.923 0.004
# NetFlow               0.942 0.934 0.940 0.933 0.936 0.937 0.003
# PEMS                  0.827 0.803 0.803 0.827 0.838 0.820 0.014
# PenDigits             0.955 0.955 0.955 0.952 0.959 0.955 0.002
# Shapes                1.000 1.000 1.000 1.000 1.000 1.000 0.000
# UWave                 0.964 0.965 0.965 0.962 0.963 0.964 0.001
# Wafer                 0.965 0.967 0.959 0.963 0.972 0.965 0.004
# WalkvsRun             1.000 1.000 1.000 1.000 1.000 1.000 0.000
# Negative log-predictive probability:
#                           0     1     2     3     4  mean   std
# ArabicDigits          0
# KickvsPunch           0.800 0.700 0.800 0.600 0.600 0.700 0.089
# LIBRAS                0.661 0.672 0.717 0.717 0.722 0.698 0.026
# NetFlow               0.946 0.893 0.968 0.957 0.961 0.945 0.027
# PEMS                  0.786 0.803 0.792 0.786 0.803 0.794 0.008
# PenDigits             0.946 0.947 0.948 0.945 0.946 0.946 0.001
# Shapes                1.000 1.000 1.000 1.000 1.000 1.000 0.000
# UWave                 0.950 0.948 0.948 0.944 0.946 0.947 0.002
# Wafer                 0.984 0.984 0.983 0.985 0.983 0.984 0.001
# WalkvsRun             1.000 1.000 1.000 1.000 1.000 1.000 0.000
# Negative log-predictive probability:
#                           0     1     2     3     4  mean   std
# ArabicDigits          0.049 0.051 0.047 0.055 0.049 0.050 0.003
# AUSLAN                2.015 1.772 1.782 2.114 1.816 1.900 0.139
# CharacterTrajectories 0.479 0.481 0.126 0.481 0.480 0.409 0.141
# CMUsubject16          0.256 0.257 0.253 0.253 0.257 0.255 0.002
# DigitShapes           0.039 0.034 0.031 0.033 0.039 0.035 0.003
# ECG                   0.548 0.515 0.543 0.573 0.537 0.543 0.019
# JapaneseVowels        0.064 0.068 0.067 0.068 0.066 0.067 0.001
# KickvsPunch           0.642 0.650 0.666 0.691 0.659 0.662 0.017
# LIBRAS                1.793 2.057 1.672 1.252 1.267 1.608 0.311
# NetFlow               0.157 0.325 0.103 0.111 0.144 0.168 0.081
# PEMS                  0.535 0.532 0.526 0.556 0.534 0.537 0.010
# PenDigits             0.176 0.177 0.181 0.189 0.179 0.181 0.005
# Shapes                0.012 0.014 0.012 0.013 0.010 0.012 0.001
# UWave                 0.175 0.195 0.188 0.200 0.190 0.189 0.008
# Wafer                 0.084 0.082 0.087 0.087 0.087 0.085 0.002
# WalkvsRun             0.067 0.067 0.066 0.067 0.065 0.066 0.001

# %% [markdown]
# ### Comparison of GPs

# %%
results_mean = {metric : {m : [np.nanmean([results_dict[m][metric][i][j] for i in range(num_experiments)]) for j, d in enumerate(datasets)] for m in models} for metric in ['nlpp', 'acc']}
results_std = {metric : {m : [np.nanstd([results_dict[m][metric][i][j] for i in range(num_experiments)]) for j, d in enumerate(datasets)] for m in models} for metric in ['nlpp', 'acc']}
results_str = {metric : {m : ['{:.3f} ± {:.3f}'.format(results_mean[metric][m][i], results_std[metric][m][i]) for i in range(len(datasets))] for m in models} for metric in ['nlpp', 'acc']}

results_mean_mean = {metric : {m : np.nanmean(results_mean[metric][m]) for m in models} for metric in ['nlpp', 'acc']}

# %% [markdown]
# #### Mean and sd. over 5 runs

# %%
idx = {i : name for i, name in enumerate(datasets)}
idx[len(datasets)] = 'Mean'

print('Accuracies:\n')
df = pandas.DataFrame.from_dict(results_str['acc'])
df = df.append(results_mean_mean['acc'], ignore_index=True).rename(index=idx)
display(df)

print('Nlpps:\n')
df = pandas.DataFrame.from_dict(results_str['nlpp'])
df = df.append(results_mean_mean['nlpp'], ignore_index=True).rename(index=idx)
display(df)
# Out:
# Accuracies:
#                              SigLSTM         SigGRU            Sig  \
# ArabicDigits           0.992 ± 0.003  0.994 ± 0.002  0.979 ± 0.004
# AUSLAN                 0.983 ± 0.003  0.978 ± 0.006  0.925 ± 0.014
# CharacterTrajectories  0.991 ± 0.003  0.925 ± 0.078  0.979 ± 0.002
# CMUsubject16           1.000 ± 0.000  1.000 ± 0.000  0.979 ± 0.017
# DigitShapes            1.000 ± 0.000  0.988 ± 0.025  1.000 ± 0.000
# ECG                    0.816 ± 0.029  0.832 ± 0.012  0.848 ± 0.010
# JapaneseVowels         0.981 ± 0.005  0.985 ± 0.004  0.982 ± 0.005
# KickvsPunch            0.900 ± 0.063  0.820 ± 0.098  0.900 ± 0.000
# LIBRAS                 0.921 ± 0.013  0.899 ± 0.031  0.923 ± 0.004
# NetFlow                0.931 ± 0.002  0.921 ± 0.012  0.937 ± 0.003
# PEMS                   0.763 ± 0.016  0.775 ± 0.019  0.820 ± 0.014
# PenDigits              0.928 ± 0.030  0.902 ± 0.048  0.955 ± 0.002
# Shapes                 1.000 ± 0.000  1.000 ± 0.000  1.000 ± 0.000
# UWave                  0.970 ± 0.004  0.968 ± 0.006  0.964 ± 0.001
# Wafer                  0.988 ± 0.005  0.978 ± 0.005  0.965 ± 0.004
# WalkvsRun              1.000 ± 0.000  1.000 ± 0.000  1.000 ± 0.000
# Mean                           0.948          0.935          0.947
#
#                                 LSTM            GRU        KConv1D
# ArabicDigits           0.985 ± 0.004  0.986 ± 0.005  0.984 ± 0.001
# AUSLAN                 0.880 ± 0.012  0.949 ± 0.014  0.784 ± 0.012
# CharacterTrajectories  0.233 ± 0.331  0.114 ± 0.050  0.941 ± 0.013
# CMUsubject16           0.924 ± 0.051  0.993 ± 0.014  0.897 ± 0.000
# DigitShapes            1.000 ± 0.000  0.812 ± 0.153  1.000 ± 0.000
# ECG                    0.782 ± 0.032  0.734 ± 0.033  0.760 ± 0.018
# JapaneseVowels         0.982 ± 0.004  0.986 ± 0.005  0.986 ± 0.002
# KickvsPunch            0.620 ± 0.075  0.600 ± 0.110  0.700 ± 0.089
# LIBRAS                 0.776 ± 0.019  0.742 ± 0.050  0.698 ± 0.026
# NetFlow                0.928 ± 0.011  0.926 ± 0.012  0.945 ± 0.027
# PEMS                   0.745 ± 0.044  0.769 ± 0.020  0.794 ± 0.008
# PenDigits              0.953 ± 0.008  0.951 ± 0.008  0.946 ± 0.001
# Shapes                 1.000 ± 0.000  0.867 ± 0.163  1.000 ± 0.000
# UWave                  0.870 ± 0.029  0.763 ± 0.225  0.947 ± 0.002
# Wafer                  0.966 ± 0.037  0.994 ± 0.002  0.984 ± 0.001
# WalkvsRun              1.000 ± 0.000  1.000 ± 0.000  1.000 ± 0.000
# Mean                           0.853          0.824          0.898
# Nlpps:
#                              SigLSTM         SigGRU            Sig  \
# ArabicDigits           0.047 ± 0.030  0.023 ± 0.006  0.071 ± 0.021
# AUSLAN                 0.106 ± 0.007  0.123 ± 0.045  0.550 ± 0.114
# CharacterTrajectories  0.031 ± 0.007  0.258 ± 0.265  0.108 ± 0.005
# CMUsubject16           0.088 ± 0.020  0.040 ± 0.009  0.089 ± 0.027
# DigitShapes            0.008 ± 0.001  0.035 ± 0.051  0.021 ± 0.001
# ECG                    0.402 ± 0.023  0.431 ± 0.037  0.356 ± 0.008
# JapaneseVowels         0.080 ± 0.031  0.053 ± 0.009  0.069 ± 0.003
# KickvsPunch            0.301 ± 0.109  0.493 ± 0.128  0.224 ± 0.014
# LIBRAS                 0.320 ± 0.045  0.346 ± 0.091  0.259 ± 0.021
# NetFlow                0.218 ± 0.009  0.259 ± 0.078  0.189 ± 0.014
# PEMS                   0.704 ± 0.130  1.100 ± 0.064  0.520 ± 0.058
# PenDigits              0.289 ± 0.127  0.399 ± 0.206  0.146 ± 0.007
# Shapes                 0.014 ± 0.004  0.012 ± 0.004  0.011 ± 0.002
# UWave                  0.113 ± 0.011  0.121 ± 0.017  0.140 ± 0.004
# Wafer                  0.048 ± 0.021  0.081 ± 0.011  0.105 ± 0.010
# WalkvsRun              0.030 ± 0.008  0.030 ± 0.008  0.023 ± 0.007
# Mean                           0.175          0.238          0.180
#
#                                 LSTM            GRU        KConv1D
# ArabicDigits           0.082 ± 0.022  0.066 ± 0.010  0.050 ± 0.003
# AUSLAN                 0.650 ± 0.071  0.248 ± 0.063  1.900 ± 0.139
# CharacterTrajectories  2.506 ± 1.007  3.523 ± 0.635  0.409 ± 0.141
# CMUsubject16           0.270 ± 0.080  0.089 ± 0.039  0.255 ± 0.002
# DigitShapes            0.013 ± 0.002  0.727 ± 0.569  0.035 ± 0.003
# ECG                    0.496 ± 0.018  0.601 ± 0.137  0.543 ± 0.019
# JapaneseVowels         0.061 ± 0.029  0.052 ± 0.005  0.067 ± 0.001
# KickvsPunch            0.696 ± 0.046  0.674 ± 0.037  0.662 ± 0.017
# LIBRAS                 0.911 ± 0.056  1.110 ± 0.248  1.608 ± 0.311
# NetFlow                0.251 ± 0.041  0.194 ± 0.011  0.168 ± 0.081
# PEMS                   1.194 ± 0.308  0.784 ± 0.111  0.537 ± 0.010
# PenDigits              0.185 ± 0.027  0.187 ± 0.043  0.181 ± 0.005
# Shapes                 0.016 ± 0.008  0.168 ± 0.142  0.012 ± 0.001
# UWave                  0.745 ± 0.151  1.168 ± 1.063  0.189 ± 0.008
# Wafer                  0.105 ± 0.086  0.029 ± 0.011  0.085 ± 0.002
# WalkvsRun              0.048 ± 0.040  0.028 ± 0.000  0.066 ± 0.001
# Mean                           0.514          0.603          0.423

# %% [markdown]
# #### Ranks over 5 runs

# %%
small_n_train = 300
small_d_idx = [i for i, d in enumerate(datasets.items()) if d[1]['n_train'] < small_n_train]
large_d_idx = [i for i, d in enumerate(datasets.items()) if d[1]['n_train'] >= small_n_train]

idx = {i : name for i, name in enumerate(datasets)}
idx[len(datasets)] = 'Avg. Rank (smaller)'
idx[len(datasets)+1] = 'Avg. Rank (larger)'
idx[len(datasets)+2] = 'Avg. Rank (all)'

print('Accuracies:\n')
df = pandas.DataFrame.from_dict(results_mean['acc']).rank(axis=1, ascending=False)
df = df.append(df.iloc[small_d_idx].mean(axis=0), ignore_index=True).append(df.iloc[large_d_idx].mean(axis=0), ignore_index=True).append(df.mean(axis=0), ignore_index=True).rename(index=idx)
display(df)

print('Nlpps:\n')
df = pandas.DataFrame.from_dict(results_mean['nlpp']).rank(axis=1)
df = df.append(df.iloc[small_d_idx].mean(axis=0), ignore_index=True).append(df.iloc[large_d_idx].mean(axis=0), ignore_index=True).append(df.mean(axis=0), ignore_index=True).rename(index=idx)
display(df)
# Out:
# Accuracies:
#                        SigLSTM  SigGRU   Sig  LSTM   GRU  KConv1D
# ArabicDigits             2.000   1.000 6.000 4.000 3.000    5.000
# AUSLAN                   1.000   2.000 4.000 5.000 3.000    6.000
# CharacterTrajectories    1.000   4.000 2.000 5.000 6.000    3.000
# CMUsubject16             1.500   1.500 4.000 5.000 3.000    6.000
# DigitShapes              2.500   5.000 2.500 2.500 6.000    2.500
# ECG                      3.000   2.000 1.000 4.000 6.000    5.000
# JapaneseVowels           6.000   3.000 4.500 4.500 2.000    1.000
# KickvsPunch              1.500   3.000 1.500 5.000 6.000    4.000
# LIBRAS                   2.000   3.000 1.000 4.000 5.000    6.000
# NetFlow                  3.000   6.000 2.000 4.000 5.000    1.000
# PEMS                     5.000   3.000 1.000 6.000 4.000    2.000
# PenDigits                5.000   6.000 1.000 2.000 3.000    4.000
# Shapes                   3.000   3.000 3.000 3.000 6.000    3.000
# UWave                    1.000   2.000 3.000 5.000 6.000    4.000
# Wafer                    2.000   4.000 6.000 5.000 1.000    3.000
# WalkvsRun                3.500   3.500 3.500 3.500 3.500    3.500
# Avg. Rank (smaller)      3.000   3.100 2.800 4.250 4.250    3.600
# Avg. Rank (larger)       2.167   3.500 3.000 4.167 4.333    3.833
# Avg. Rank (all)          2.688   3.250 2.875 4.219 4.281    3.688
# Nlpps:
#                        SigLSTM  SigGRU   Sig  LSTM   GRU  KConv1D
# ArabicDigits             2.000   1.000 5.000 6.000 4.000    3.000
# AUSLAN                   1.000   2.000 4.000 5.000 3.000    6.000
# CharacterTrajectories    1.000   3.000 2.000 5.000 6.000    4.000
# CMUsubject16             2.000   1.000 3.000 6.000 4.000    5.000
# DigitShapes              1.000   4.000 3.000 2.000 6.000    5.000
# ECG                      2.000   3.000 1.000 4.000 6.000    5.000
# JapaneseVowels           6.000   2.000 5.000 3.000 1.000    4.000
# KickvsPunch              2.000   3.000 1.000 6.000 5.000    4.000
# LIBRAS                   2.000   3.000 1.000 4.000 5.000    6.000
# NetFlow                  4.000   6.000 2.000 5.000 3.000    1.000
# PEMS                     3.000   5.000 1.000 6.000 4.000    2.000
# PenDigits                5.000   6.000 1.000 3.000 4.000    2.000
# Shapes                   4.000   2.000 1.000 5.000 6.000    3.000
# UWave                    1.000   2.000 3.000 5.000 6.000    4.000
# Wafer                    2.000   3.000 5.000 6.000 1.000    4.000
# WalkvsRun                4.000   3.000 1.000 5.000 2.000    6.000
# Avg. Rank (smaller)      2.800   2.900 2.200 4.700 4.000    4.400
# Avg. Rank (larger)       2.333   3.333 2.833 4.833 4.333    3.333
# Avg. Rank (all)          2.625   3.062 2.438 4.750 4.125    4.000
